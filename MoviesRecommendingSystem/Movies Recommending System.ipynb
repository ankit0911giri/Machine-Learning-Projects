# %% [markdown]
# ### Source Kaggle Netflix movies dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
movies = pd.read_csv("netflix_titles.csv")

# %%
movies.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
movies.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
movies.shape
# Out:
# (8807, 12)

# %%
movies.dropna(inplace = True)

# %%
movies.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
movies.shape
# Out:
# (5332, 12)

# %%
movies = movies[["title","director","cast","release_year","listed_in","description"]]

# %%
movies.head(5)
# Out:
#                             title             director  \
# 7                         Sankofa         Haile Gerima
# 8   The Great British Baking Show      Andy Devonshire
# 9                    The Starling       Theodore Melfi
# 12                   Je Suis Karl  Christian Schwochow
# 24                          Jeans           S. Shankar
#
#                                                  cast  release_year  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...          1993
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...          2021
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...          2021
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...          2021
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...          1998
#
#                                            listed_in  \
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas
# ...

# %%
movies.isna().sum()
# Out:
# title           0
# director        0
# cast            0
# release_year    0
# listed_in       0
# description     0
# dtype: int64

# %%
movies.shape
# Out:
# (5332, 6)

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.iloc[1].listed_in
# Out:
# 'British TV Shows, Reality TV'

# %%
movies.release_year.value_counts()
# Out:
# release_year
# 2017    657
# 2018    648
# 2016    577
# 2019    519
# 2020    442
#        ...
# 1945      1
# 1946      1
# 1942      1
# 1947      1
# 1944      1
# Name: count, Length: 72, dtype: int64

# %%
movies.loc[7].listed_in
# Out:
# 'Dramas, Independent Movies, International Movies'

# %%
movies.iloc[0].listed_in
# Out:
# 'Dramas, Independent Movies, International Movies'

# %%
movies["description"][7]
# Out:
# 'On a photo shoot in Ghana, an American model slips back in time, becomes enslaved on a plantation and bears witness to the agony of her ancestral past.'

# %%
movies["cast"][7]
# Out:
# 'Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra Duah, Nick Medley, Mutabaruka, Afemo Omilami, Reggie Carter, Mzuri'

# %%
movies.head(2)
# Out:
#                            title         director  \
# 7                        Sankofa     Haile Gerima
# 8  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  release_year  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...          1993
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...          2021
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description
# 7  On a photo shoot in Ghana, an American model s...
# 8  A talented batch of amateur bakers face off in...

# %%
def castNames(movies):
    name = []
    for i in movies["cast"]:
        name.append(movies["cast"[i]])
    return name

# %%
castNames(movies)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 castNames(movies)
#
# Cell In[38], line 4, in castNames(movies)
#       2 name = []
#       3 for i in movies["cast"]:
# ----> 4     name.append(movies["cast"[i]])
#       5 return name
#
# TypeError: string indices must be integers, not 'str'

# %%
color = pd.Series(["Red","Blue","Green","Yellow"])
color
# Out:
# 0       Red
# 1      Blue
# 2     Green
# 3    Yellow
# dtype: object

# %%
for i in color:
    print(i)
# Out:
# Red
# Blue
# Green
# Yellow

# %%
type(movies["cast"])
# Out:
# pandas.core.series.Series

# %%
for i in movies["cast"].iloc[0]:
    movies["cast"].apply()
# Out:
# K
# o
# f
# i
#
# G
# h
# a
# n
# a
# b
# a
# ,
#
# O
# y
# a
# f
# u
# n
# m
# i
# k
# e
#
# O
# g
# u
# n
# l
# a
# n
# o
# ,
#
# A
# l
# e
# x
# a
# n
# d
# r
# a
#
# D
# u
# a
# h
# ,
#
# N
# i
# c
# k
#
# M
# e
# d
# l
# e
# y
# ,
#
# M
# u
# t
# a
# b
# a
# r
# u
# k
# a
# ,
#
# A
# f
# e
# m
# o
#
# O
# m
# i
# l
# a
# m
# i
# ,
#
# R
# e
# g
# g
# i
# e
#
# C
# a
# r
# t
# e
# r
# ,
#
# M
# z
# u
# r
# i
